# %% [markdown]
# What is the data type of the result of: 6 / 2?

# %%
a=6/2
type(a)
# Out:
# float

# %% [markdown]
# What is the type of the result of: 6 // 2? (Note the double slash //.)

# %%
a=6//2
type(a)
# Out:
# int

# %% [markdown]
# What is the type of the result of: "hello" == "world"?

# %%
print(type("hello"=="World"))
# Out:
# <class 'bool'>

# %% [markdown]
# Write the code to convert this phone number 123-456-7890 to a string.

# %%
p_number = 1234567890
p_number_string = str(p_number)
print(type(p_number))
type(p_number_string)
# Out:
# <class 'int'>
# str

# %%
p="123-456-7890"
p
# Out:
# '123-456-7890'

# %% [markdown]
# Write the code to convert this number representing financial value "1234.56" to a floating point number.

# %%
financial_value = "1234.56"
financial_value = float(financial_value)
print(type(financial_value))
financial_value
# Out:
# <class 'float'>
# 1234.56

# %% [markdown]
# Write the code to convert the following number representing employee ID "1001" to an integer.

# %%
employee_id = int("1001")
print(employee_id)
type(employee_id)
# Out:
# 1001
# int

# %%
int(3.99)
# Out:
# 3

# %% [markdown]
# Aman_jha_1024170215
